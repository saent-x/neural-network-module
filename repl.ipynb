// %%
#r "nuget:NumSharp"
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>NumSharp, 0.30.0</span></li></ul></div></div>

// %%
using NumSharp;

// %%
NDArray arr_1 = new float[3]{1,2,3};
NDArray arr_2 = new float[3]{3,2,7};

var result = np.dot(arr_1, arr_2);

result
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 28 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>dtype</td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.double?view=net-7.0">System.Double</a></span></td></tr><tr><td>typecode</td><td><span>Double</span></td></tr><tr><td>shape</td><td><div class="dni-plaintext"><pre>28</pre></div></td></tr><tr><td>ndim</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>size</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>dtypesize</td><td><div class="dni-plaintext"><pre>8</pre></div></td></tr><tr><td>order</td><td><div class="dni-plaintext"><pre>C</pre></div></td></tr><tr><td>strides</td><td><div class="dni-plaintext"><pre>[  ]</pre></div></td></tr><tr><td>flat</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 28 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>dty
// ...

// %%
0.10*np.random.randn(4,3)
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>[ -0.06302071127305868, 0.062393278321713486, -0.0884390667219156, 0.06754888046326492, -0.012887329374437227, 0.2137926144733997, -0.05071360283021677, 0.2086795923080291, -0.1582298676566012, -0.0813759440500216, -0.09574069195683575, -0.0884902557561063 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>dtype</td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.double?view=net-7.0">System.Double</a></span></td></tr><tr><td>typecode</td><td><span>Double</span></td></tr><tr><td>shape</td><td><div class="dni-plaintext"><pre>[[-0.06302071127305868, 0.062393278321713486, -0.0884390667219156],
// [0.06754888046326492, -0.012887329374437227, 0.2137926144733997],
// [-0.05071360283021677, 0.2086795923080291, -0.1582298676566012],
// ...
